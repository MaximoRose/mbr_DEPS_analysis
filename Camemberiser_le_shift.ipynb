# %% [markdown]
# # Juste un fichier pour transformer les data du Shift Project en camembert, Médine Normandie, LoL
#
#
# Le rapport en question [->](https://theshiftproject.org/article/decarbonons-la-culture-rapport-intermediaire-shift/)

# %%
import matplotlib.pyplot as plt

# Données du rapport
labels = ['Vidéos à la demande', 'Jeux vidéo et Twitch', 'Streaming musical', 'Tubes (YouTube, Vimeo, etc.)', 'Pornographie', 'Autre']
values = [30, 9, 0.5, 10, 22, (100 - 30 - 9 -0.5 -10 -22)]
titre = "Répartition des types de contenus consommés en ligne, pour 100Go"
#couleur_camembert_serge_gainsbourg = ["#f2cb26", "#00a154", "#0083c6", "#dc0036", "#fc8934", "#e3e3e3", "#fb85a7", "#00b3f0"]
couleur_camembert_serge_gainsbourg = ["#00a154", "#00a154", "#00a154", "#00a154", "#fc8934", "#e3e3e3", "#fb85a7", "#00b3f0"]
affichage_pourcentage = "%1.1f%%"
eclatement_entre_les_tranches_de_calandos = 0.005

# CAMEMBERISATION
explode = (eclatement_entre_les_tranches_de_calandos,)*len(labels)
fig = plt.figure(figsize = (10, 7))
plt.pie(values, labels = labels, autopct=affichage_pourcentage, colors=couleur_camembert_serge_gainsbourg, explode = explode)
plt.title(titre, size = 16)
plt.show()

# %% [markdown]
# # Petites stats INSEE pour le bonus
#
# |   | Femmes | Hommes | Total |
# | --- | --- | --- | --- |
# | 15 à 24 ans | 1 248 | 1 532 |2 780 |
# | 25 à 49 ans | 8 703 | 9 435 | 18 138 |
# | 50 à 64 ans | 4 142 | 4 228 | 8 370 |
# | Total 15 à 64 ans | 14 094 | 15 194 | 29 288 |

# %%
print (str((18138 + 8370)/29288))
# Out:
# 0.905080579076755
